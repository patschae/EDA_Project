# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from openpyxl import load_workbook

# Read excel file and create dict object, containing all sheets
sheet_names = pd.read_excel('/Users/p/Downloads/neueFische/EDA_Project/Data/Muesli Project raw data.xlsx', sheet_name=None)

# Show all sheet names
sheet_names.keys()
# Out:
# dict_keys(['Orders', 'Order Process Data', 'InternData Study', 'Campaign Data'])

# %%
# Create a data frame for every sheet
i = 1
for name in sheet_names:
    # For every sheet in the workbook, create a new data frame
    exec(f"df_{i} = pd.DataFrame(sheet_names[name])")
    # Show the name of the sheet and its data frame created
    print(f"Created 'df_{i}' from '{name}' sheet.")
    i += 1
# Out:
# Created 'df_1' from 'Orders' sheet.
# Created 'df_2' from 'Order Process Data' sheet.
# Created 'df_3' from 'InternData Study' sheet.
# Created 'df_4' from 'Campaign Data' sheet.

# %%
df_2.head()
# Out:
#    Row ID        Order ID Order Date On Truck Scan Date            Ship Mode
# 0     646  CA-2020-126221 2020-12-30         2021-01-06  Standard Processing
# 1     907  CA-2020-143259 2020-12-30         2021-01-06  Standard Processing
# 2     908  CA-2020-143259 2020-12-30         2021-01-06  Standard Processing
# 3     909  CA-2020-143259 2020-12-30         2021-01-06  Standard Processing
# 4    1297  CA-2020-115427 2020-12-30         2021-01-06  Standard Processing

# %%
df_4.head()
# Out:
#          Order ID Arrival Scan Date     Customer Name
# 0  CA-2019-109666        2019-05-03      Kunst Miller
# 1  CA-2019-138933        2019-05-03       Jack Lebron
# 2  CA-2019-130001        2019-05-03  Heather Kirkland
# 3  CA-2019-113061        2019-05-06         Ed Ludwig
# 4  CA-2019-162138        2019-05-06       Grace Kelly

# %%
merge_df_2_4 = df_2.merge(df_4, on='Order ID')
merge_df_2_4
# Out:
#      Row ID        Order ID Order Date On Truck Scan Date  \
# 0      5012  US-2020-139647 2020-05-11         2020-05-13
# 1      9520  US-2020-104451 2020-05-08         2020-05-13
# 2      3828  CA-2020-141733 2020-05-07         2020-05-13
# 3      3829  CA-2020-141733 2020-05-07         2020-05-13
# 4      3830  CA-2020-141733 2020-05-07         2020-05-13
# ..      ...             ...        ...                ...
# 663    7110  CA-2019-109666 2019-04-19         2019-04-29
# 664    7111  CA-2019-109666 2019-04-19         2019-04-29
# 665    7112  CA-2019-109666 2019-04-19         2019-04-29
# 666    7113  CA-2019-109666 2019-04-19         2019-04-29
# 667    7114  CA-2019-109666 2019-04-19         2019-04-29
#
#                Ship Mode Arrival Scan Date   Customer Name
# 0                Express        2020-05-15    Todd Sumrall
# 1    Standard Processing        2020-05-15  Michelle Moray
# 2    Standard Processing        2020-05-15     Rick Wilson
# 3    Standard Processing        2020-05-15     Rick Wilson
# 4    Standard Processing        2020-05-15     Rick Wilson
# ..                   ...               ...             ...
# 663  Standard Processing        2019-05-03    Kunst Miller
# 664  Standard Processing        2019-05-03    Kunst Miller
# 665  Standard Processing        2019-05-03    Kunst Miller
# 666  Standard Processing        2019-05-03    Kunst Miller
# 667  Standard Processing        2019-05-03    Kunst Miller
#
# [668 rows x 7 columns]

# %%
def format_columns(df,col):
    df.columns = df.columns.str.lower().str.replace(' ', '_').str.strip()
    df.columns = df.columns.str.replace('-', '_')
    df.columns = df.columns.str.replace('/', '_')
    df = df.sort_values(by=col, inplace=True)

    return df

format_columns(merge_df_2_4, 'order_date')

# %%
merge_df_2_4.drop('row_id', inplace=True, axis=1)

# %%
#Check for NaN values
merge_df_2_4.isnull().any()
# Out:
# order_id              False
# order_date            False
# on_truck_scan_date    False
# ship_mode             False
# arrival_scan_date     False
# customer_name         False
# dtype: bool

# %%
format_columns(df_1, 'order_date')

df_1 = df_1[df_1.drop['']]

df_1
# Out:
#       index        order_id order_date       ship_mode customer_id  \
# 3225   7981  CA-2017-103800 2017-01-03  Standard Class    DP-13000
# 4785    741  CA-2017-112326 2017-01-04  Standard Class    PO-19195
# 5655    742  CA-2017-112326 2017-01-04  Standard Class    PO-19195
# 1778    740  CA-2017-112326 2017-01-04  Standard Class    PO-19195
# 7229   1760  CA-2017-141817 2017-01-05  Standard Class    MB-18085
# ...     ...             ...        ...             ...         ...
# 1204   5092  CA-2020-156720 2020-12-30  Standard Class    JM-15580
# 1324    646  CA-2020-126221 2020-12-30  Standard Class    CC-12430
# 5750   1298  CA-2020-115427 2020-12-30  Standard Class    EB-13975
# 8211    907  CA-2020-143259 2020-12-30  Standard Class    PO-18865
# 5684    909  CA-2020-143259 2020-12-30  Standard Class    PO-18865
#
#           customer_name origin_channel country_region           city  \
# 3225      Darren Powers          Email  United States        Houston
# 4785      Phillina Ober       Facebook  United States     Naperville
# 5655      Phillina Ober       Facebook  United States     Naperville
# 1778      Phillina Ober       Facebook  United States     Naperville
# 7229         Mick Brown          Email  United States   Philadelphia
# ...                 ...            ...            ...            ...
# 1204      Jill Matthias          Email  United States       Loveland
# 1324        Chuck Clark       Facebook  United States       Columbus
# 5750         Erica Bern          Sales  United States      Fairfield
# 8211  Patrick O'Donnell          Email  United States  New York City
# 5684  Patrick O'Donnell          Email  United States  New York City
#
#              state  postal_code   region        category        sub_category  \
# 3225         Texas      77095.0  Central    Power Muesli       Nuts and more
# 4785      Illinois      60540.0  Central    Power Muesli           Steel Cut
# 5655      Illinois      60540.0  Central    Power Muesli   Super Fibre Boost
# 1778      Illinois      60540.0  Central    Power Muesli  No Taste All Power
# 7229  Pennsylvania      19143.0     East    Power Muesli  Super Mega Protein
# ...            ...          ...      ...             ...                 ...
# 1204      Colorado      80538.0     West    Power Muesli     Maple Sweetened
# 1324       Indiana      47201.0  Central    Power Muesli        Mega Protein
# 5750    California      94533.0     West    Power Muesli   Super Fibre Boost
# 8211      New York      10009.0     East  Toasted Muesli          With Fruit
# 5684      New York      10009.0     East    Power Muesli   Super Fibre Boost
#
#            product_id    sales  quantity  discount   profit
# 3225  OFF-PA-10000174   16.448         2       0.2   5.5512
# 4785  OFF-ST-10002743  272.736         3       0.2 -64.7748
# 5655  OFF-BI-10004094    3.540         2       0.8  -5.4870
# 1778  OFF-LA-10003223   11.784         3       0.2   4.2717
# 7229  OFF-AR-10003478   19.536         3       0.2   4.8840
# ...               ...      ...       ...       ...      ...
# 1204  OFF-FA-10003472    3.024         3       0.2  -0.6048
# 1324  OFF-AP-10002457  209.300         2       0.0  56.5110
# 5750  OFF-BI-10004632   20.720         2       0.2   6.4750
# 8211  FUR-BO-10003441  323.136         4       0.2  12.1176
# 5684  OFF-BI-10003684   52.776         3       0.2  19.7910
#
# [9994 rows x 19 columns]

# %%
merge_df_2_4
merged_df = pd.merge(merge_df_2_4, df_1, on=['order_id',])
merge_df_2_4 = df_2.merge(df_4, on='order')
# Out:
#            order_id order_date on_truck_scan_date            ship_mode  \
# 667  CA-2019-109666 2019-04-19         2019-04-29  Standard Processing
# 661  CA-2019-109666 2019-04-19         2019-04-29  Standard Processing
# 662  CA-2019-109666 2019-04-19         2019-04-29  Standard Processing
# 666  CA-2019-109666 2019-04-19         2019-04-29  Standard Processing
# 664  CA-2019-109666 2019-04-19         2019-04-29  Standard Processing
# ..              ...        ...                ...                  ...
# 4    CA-2020-141733 2020-05-07         2020-05-13  Standard Processing
# 3    CA-2020-141733 2020-05-07         2020-05-13  Standard Processing
# 2    CA-2020-141733 2020-05-07         2020-05-13  Standard Processing
# 1    US-2020-104451 2020-05-08         2020-05-13  Standard Processing
# 0    US-2020-139647 2020-05-11         2020-05-13              Express
#
#     arrival_scan_date   customer_name
# 667        2019-05-03    Kunst Miller
# 661        2019-05-03    Kunst Miller
# 662        2019-05-03    Kunst Miller
# 666        2019-05-03    Kunst Miller
# 664        2019-05-03    Kunst Miller
# ..                ...             ...
# 4          2020-05-15     Rick Wilson
# 3          2020-05-15     Rick Wilson
# 2          2020-05-15     Rick Wilson
# 1          2020-05-15  Michelle Moray
# 0          2020-05-15    Todd Sumrall
#
# [668 rows x 6 columns]
